# %%
import torch

# %%
import tensorflow

# %%
import smbus
bus = smbus.SMBus(1)

# %%
import cv2

# %%
# !apt list --installed
# Out:
# Listing... Done
# accountsservice/bionic,now 0.6.45-1ubuntu1 arm64 [installed,automatic]
# acl/bionic,now 2.2.52-3build1 arm64 [installed,automatic]
# activity-log-manager/bionic,now 0.9.7-0ubuntu26 arm64 [installed,automatic]
# adduser/bionic,now 3.116ubuntu1 all [installed]
# adium-theme-ubuntu/bionic,now 0.3.4-0ubuntu4 all [installed,automatic]
# adwaita-icon-theme/bionic,now 3.28.0-1ubuntu1 all [installed,automatic]
# aisleriot/bionic,now 1:3.22.5-1 arm64 [installed,automatic]
# alsa-base/bionic,now 1.0.25+dfsg-0ubuntu5 all [installed,automatic]
# alsa-utils/bionic,now 1.1.3-1ubuntu1 arm64 [installed]
# anacron/bionic,now 2.3-24 arm64 [installed,automatic]
# apg/bionic,now 2.2.3.dfsg.1-5 arm64 [installed,automatic]
# app-install-data-partner/bionic,now 16.04 all [installed,automatic]
# apparmor/bionic-updates,bionic-security,now 2.12-4ubuntu5.1 arm64 [installed]
# appmenu-qt/bionic,now 0.2.7+14.04.20140305-0ubuntu2 arm64 [installed,automatic]
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------
# absl-py                       0.9.0
# Adafruit-GPIO                 1.0.4
# Adafruit-MotorHAT             1.4.0
# Adafruit-PureIO               1.0.4
# Adafruit-SSD1306              1.6.2
# apt-clone                     0.2.1
# apturl                        0.5.2
# asn1crypto                    0.24.0
# astor                         0.8.1
# attrs                         19.3.0
# backcall                      0.1.0
# beautifulsoup4                4.6.0
# bleach                        3.1.0
# blinker                       1.4
# Brlapi                        0.6.6
# certifi                       2018.1.18
# chardet                       3.0.4
# cryptography                  2.1.4
# cupshelpers                   1.0
# decorator                     4.4.1
# defer                         1.0.6
# defusedxml                    0.6.0
# distro-info                   0.18ubuntu0.18.04.1
# ...

# %%
# !brew list
# Out:
# /bin/sh: 1: brew: not found
