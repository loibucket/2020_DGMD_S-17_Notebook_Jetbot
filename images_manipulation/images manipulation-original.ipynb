# %%
import cv2

# %%
import keras

# %%
from skimage import io
img = io.imread('/Users/ricardovillamil/Downloads/puppy.jpg')
io.imshow(img)

# %%
img.shape
# Out:
# (331, 500, 3)

# %%
from skimage import color
from skimage import data
from pylab import *

img_hsv = color.rgb2hsv(img)

# %%
img_rgb = color.hsv2rgb(img_hsv)

# %%
figure(0)
io.imshow(img_hsv)
figure(1)
io.imshow(img_rgb)

# %%
img1 = cv2.imread('/Users/ricardovillamil/Downloads/puppy.jpg')
img2 = cv2.imread('/Users/ricardovillamil/Downloads/cat.jpeg')

alpha = 0.8
beta = 0.2

final_image = cv2.addWeighted(img1, alpha, img2, beta, 0.0)

figure(0)
io.imshow(img2)
figure(1)
io.imshow(final_image)

# %%
import numpy as np

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img2, "I am a cat", (230, 50), font, 0.8, (0, 255, 0), 2, cv2.LINE_AA)
io.imshow(img2)

# %%
image_original = img2
image_median = cv2.imread('/Users/ricardovillamil/Downloads/cat.jpeg')
image_gaussian = cv2.imread('/Users/ricardovillamil/Downloads/cat.jpeg')
image_bilateral = cv2.imread('/Users/ricardovillamil/Downloads/cat.jpeg')

image_median = cv2.medianBlur(img2, 9)
image_gaussian = cv2.GaussianBlur(img2, (9,9), 10)
image_bilateral = cv2.bilateralFilter(img2, 9, 100, 75)

# %%
figure(0)
io.imshow(image_original)
figure(1)
io.imshow(image_median)
figure(2)
io.imshow(image_gaussian)
figure(3)
io.imshow(image_bilateral)

# %%
cv2.GaussianBlur(image_original, (3, 3), 0)
gray = cv2.cvtColor(image_original, cv2.COLOR_BGR2GRAY)
src_eqlzd = cv2.equalizeHist(gray)
figure(0)
io.imshow(gray)
figure(1)
io.imshow(src_eqlzd)

# %%
grad_x = cv2.Sobel(gray, cv2.CV_16S, 1, 0, ksize=3, scale=1, delta=0, borderType=cv2.BORDER_DEFAULT)

# %%
grad_y = cv2.Sobel(gray, cv2.CV_16S, 0, 1, ksize=3, scale=1, delta=0, borderType=cv2.BORDER_DEFAULT)
abs_grad_x = cv2.convertScaleAbs(grad_x)
abs_grad_y = cv2.convertScaleAbs(grad_y)
grad = cv2.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0)
io.imshow(grad)

# %%
edges = cv2.Canny(gray,40,55,apertureSize = 3)
edges = cv2.bitwise_not(edges)
cv2.imwrite("/Users/ricardovillamil/Downloads/catlines.jpg", edges)
catlines = cv2.imread("/Users/ricardovillamil/Downloads/catlines.jpg")
io.imshow(catlines)
